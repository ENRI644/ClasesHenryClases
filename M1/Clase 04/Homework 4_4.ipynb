# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("hospitales2.csv")
#df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 20 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   WKT         36 non-null     object
#  1   ID          36 non-null     float64
#  2   NOMBRE      36 non-null     object
#  3   NOM_MAP     36 non-null     object
#  4   OBJETO      36 non-null     object
#  5   CALLE       36 non-null     object
#  6   ALTURA      36 non-null     int64
#  7   DOM_NORMA   36 non-null     object
#  8   DOM_GEO     36 non-null     object
#  9   TELEFONO    36 non-null     object
#  10  GUARDIA     34 non-null     object
#  11  FAX         35 non-null     object
#  12  WEB         13 non-null     object
#  13  COD_POSTAL  36 non-null     object
#  14  TIPO        36 non-null     object
#  15  TIPO_ESPEC  35 non-null     object
#  16  MOD_AT_1    35 non-null     object
#  17  MOD_AT_2    35 non-null     object
#  18  DEPEND_ADM  36 non-null     object
# ...

# %%
df[["WKT","DOM_NORMA","NOMBRE"]].to_csv("salida.csv")
salida = pd.read_csv("salida.csv")
type(salida)
# Out:
# pandas.core.frame.DataFrame

# %%
auxLat= []
auxLong=[]
for i in salida["WKT"]:
    i.split()
    auxLat.append(i[1].strip("("))
    auxLong.append(i[2].strip(")"))
salida.insert(0,"LATITUD",auxLat)
salida.insert(1,"LONGITUD",auxLong)
del(salida["WKT"])
salida
# Out:
#    LATITUD LONGITUD  Unnamed: 0                             DOM_NORMA  \
# 0        O        I           0          MONTES DE OCA, MANUEL AV. 40
# 1        O        I           1                            GALLO 1330
# 2        O        I           2            SANCHEZ DE BUSTAMANTE 2529
# 3        O        I           3                         BRANDSEN 2570
# 4        O        I           4                      CASEROS AV. 2061
# 5        O        I           5                   DIAZ VELEZ AV. 4821
# 6        O        I           6           FINOCHIETTO ENRIQUE DR. 849
# 7        O        I           7              CARRILLO, RAMON, DR. 315
# 8        O        I           8              CARRILLO, RAMON, DR. 375
# 9        O        I           9         DON PEDRO DE MENDOZA AV. 1795
# 10       O        I          10                        ECHEVERRIA 955
# 11       O        I          11                 LUCA, ESTEBAN DE 2151
# ...
